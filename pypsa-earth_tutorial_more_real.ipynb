# %% [markdown]
# ### realistic example

# %%
import pypsa
import matplotlib.pyplot as plt
import cartopy.crs as ccrs


n = pypsa.examples.scigrid_de(from_master=True)
# Out:
# WARNING:pypsa.io:Importing network from PyPSA version v0.17.1 while current version is v0.28.0. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.io:Imported network scigrid-de.nc has buses, generators, lines, loads, storage_units, transformers

# %% [markdown]
# this network includes time-varying data, now is the time to look at another attribute of n: n.snapshots. Snapshots is the PyPSA terminology for time steps. In most cases, they represent a particular hour. They can be a pandas.DatetimeIndex or any other list-like attributes.

# %%
n.lines.s_max_pu = 0.7
n.lines.loc[["316", "527", "602"], "s_nom"] = 1715
n.snapshots
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                '2011-01-01 10:00:00', '2011-01-01 11:00:00',
#                '2011-01-01 12:00:00', '2011-01-01 13:00:00',
#                '2011-01-01 14:00:00', '2011-01-01 15:00:00',
#                '2011-01-01 16:00:00', '2011-01-01 17:00:00',
#                '2011-01-01 18:00:00', '2011-01-01 19:00:00',
#                '2011-01-01 20:00:00', '2011-01-01 21:00:00',
#                '2011-01-01 22:00:00', '2011-01-01 23:00:00'],
#               dtype='datetime64[ns]', name='snapshot', freq=None)

# %%
n.loads_t.p_set.head(3)
# Out:
# Load                          1          3          4           6           7  \
# snapshot
# 2011-01-01 00:00:00  231.716206  40.613618  66.790442  196.124424  147.804142
# 2011-01-01 01:00:00  221.822547  38.879526  63.938670  187.750439  141.493303
# 2011-01-01 02:00:00  213.127360  37.355494  61.432348  180.390839  135.946929
#
# Load                          8          9         11          14          16  \
# snapshot
# 2011-01-01 00:00:00  123.671946  83.637404  73.280624  175.260369  298.900165
# 2011-01-01 01:00:00  118.391487  80.066312  70.151738  167.777223  286.137932
# 2011-01-01 02:00:00  113.750678  76.927805  67.401871  161.200550  274.921657
#
# Load                 ...   382_220kV   384_220kV   385_220kV  391_220kV  \
# snapshot             ...
# 2011-01-01 00:00:00  ...  202.010114  222.695091  212.621816  77.570241
# 2011-01-01 01:00:00  ...  193.384825  213.186609  203.543436  74.258201
# 2011-01-01 02:00:00  ...  185.804364  204.829941  195.564769  71.347365
#
# Load                 403_220kV  404_220kV  413_220kV  421_220kV  450_220kV  \
# snapshot
# 2011-01-01 00:00:00  16.148970   0.092794  58.427056  67.013686  38.449243
# 2011-01-01 01:00:00  15.459452   0.088831  55.932378  64.152382  36.807564
# 2011-01-01 02:00:00  14.853460   0.085349  53.739893  61.637683  35.364750
#
# Load                 458_220kV
# snapshot
# 2011-01-01 00:00:00  66.752618
# 2011-01-01 01:00:00  63.902460
# 2011-01-01 02:00:00  61.397558
#
# [3 rows x 485 columns]

# %% [markdown]
# We can use simple pandas syntax, to create an overview of the load time series…

# %%
n.loads_t.p_set.sum(axis=1).div(1e3).plot(ylim=[0, 60], ylabel="MW")
# Out:
# <AxesSubplot:xlabel='snapshot', ylabel='MW'>

# %% [markdown]
# … and the capacity factor time series:

# %%
n.generators_t.p_max_pu.T.groupby(n.generators.carrier).mean().T.plot(ylabel="p.u.")
# Out:
# <AxesSubplot:xlabel='snapshot', ylabel='p.u.'>

# %% [markdown]
# We can also inspect the total power plant capacities per technology…

# %%
n.generators.groupby("carrier").p_nom.sum().div(1e3).plot.barh()
plt.xlabel("GW")
# Out:
# Text(0.5, 0, 'GW')

# %% [markdown]
# … and plot the regional distribution of loads…

# %%
load = n.loads_t.p_set.sum(axis=0).groupby(n.loads.bus).sum()
fig = plt.figure()
ax = plt.axes(projection=ccrs.EqualEarth())

n.plot(
    ax=ax,
    bus_sizes=load / 2e5,
)
# Out:
# c:\Users\Alejandro\miniconda3\envs\pypsa-earth\lib\site-packages\cartopy\mpl\feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
# (<matplotlib.collections.PatchCollection at 0x211d20a61d0>,
#  <matplotlib.collections.LineCollection at 0x211d703bfd0>,
#  <matplotlib.collections.LineCollection at 0x211da304910>)

# %% [markdown]
# … and power plant capacities:

# %%
capacities = n.generators.groupby(["bus", "carrier"]).p_nom.sum()

# %% [markdown]
# For plotting we need to assign some colors to the technologies.

# %%
import random
import pandas as pd

# Get all unique carrier names from generators and storage units
carriers = pd.Index(n.generators.carrier.tolist() + n.storage_units.carrier.tolist()).unique()

# Filter out any already existing ones (optional)
missing_carriers = carriers.difference(n.carriers.index)

# Assign a random color to each missing carrier
colors = ["#%06x" % random.randint(0, 0xFFFFFF) for _ in missing_carriers]

# Add them to the network
n.madd("Carrier", missing_carriers, color=colors)
# Out:
# Index(['Gas', 'Hard Coal', 'Run of River', 'Waste', 'Brown Coal', 'Oil',
#        'Storage Hydro', 'Other', 'Multiple', 'Nuclear', 'Geothermal',
#        'Wind Offshore', 'Wind Onshore', 'Solar', 'Pumped Hydro'],
#       dtype='object')

# %% [markdown]
# we want to see which color represents which technology, we cann add a legend using the add_legend_patches function of PyPSA

# %%
from pypsa.plot import add_legend_patches



fig = plt.figure()
ax = plt.axes(projection=ccrs.EqualEarth())

n.plot(
    ax=ax,
    bus_sizes=capacities / 2e4,
)

add_legend_patches(
    ax, colors, carriers, legend_kw=dict(frameon=False, bbox_to_anchor=(0, 1))
)
# Out:
# c:\Users\Alejandro\miniconda3\envs\pypsa-earth\lib\site-packages\cartopy\mpl\feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %%
n.storage_units.head(3)
# Out:
#                               bus  p_nom       carrier  marginal_cost  \
# StorageUnit
# 100_220kV Pumped Hydro  100_220kV  144.5  Pumped Hydro            3.0
# 114 Pumped Hydro              114  138.0  Pumped Hydro            3.0
# 121 Pumped Hydro              121  238.0  Pumped Hydro            3.0
#
#                         max_hours  efficiency_store  efficiency_dispatch  \
# StorageUnit
# 100_220kV Pumped Hydro        6.0              0.95                 0.95
# 114 Pumped Hydro              6.0              0.95                 0.95
# 121 Pumped Hydro              6.0              0.95                 0.95
#
#                        control type  p_nom_mod  ...  build_year  lifetime  \
# StorageUnit                                     ...
# 100_220kV Pumped Hydro      PQ             0.0  ...           0       inf
# 114 Pumped Hydro            PQ             0.0  ...           0       inf
# 121 Pumped Hydro            PQ             0.0  ...           0       inf
#
#                         state_of_charge_initial  \
# StorageUnit
# 100_220kV Pumped Hydro                      0.0
# 114 Pumped Hydro                            0.0
# 121 Pumped Hydro                            0.0
#
#                         state_of_charge_initial_per_period  \
# StorageUnit
# 100_220kV Pumped Hydro                               False
# 114 Pumped Hydro                                     False
# 121 Pumped Hydro                                     False
#
#                         state_of_charge_set  cyclic_state_of_charge  \
# StorageUnit
# 100_220kV Pumped Hydro                  NaN                   False
# 114 Pumped Hydro                        NaN                   False
# 121 Pumped Hydro                        NaN                   False
#
#                         cyclic_state_of_charge_per_period  standing_loss  \
# StorageUnit
# 100_220kV Pumped Hydro                               True            0.0
# 114 Pumped Hydro                                     True            0.0
# 121 Pumped Hydro                                     True            0.0
#
#                         inflow  p_nom_opt
# StorageUnit
# 100_220kV Pumped Hydro     0.0        0.0
# 114 Pumped Hydro           0.0        0.0
# 121 Pumped Hydro           0.0        0.0
#
# [3 rows x 30 columns]

# %%
n.optimize(solver_name="glpk")
# Out:
# WARNING:pypsa.components:The following transformers have zero r, which could break the linear load flow:
# Index(['2', '5', '10', '12', '13', '15', '18', '20', '22', '24', '26', '30',
#        '32', '37', '42', '46', '52', '56', '61', '68', '69', '74', '78', '86',
#        '87', '94', '95', '96', '99', '100', '104', '105', '106', '107', '117',
#        '120', '123', '124', '125', '128', '129', '138', '143', '156', '157',
#        '159', '160', '165', '184', '191', '195', '201', '220', '231', '232',
#        '233', '236', '247', '248', '250', '251', '252', '261', '263', '264',
#        '267', '272', '279', '281', '282', '292', '303', '307', '308', '312',
#        '315', '317', '322', '332', '334', '336', '338', '351', '353', '360',
#        '362', '382', '384', '385', '391', '403', '404', '413', '421', '450',
#        '458'],
#       dtype='object', name='Transformer')
# WARNING:pypsa.components:The following transformers have zero r, which could break the linear load flow:
# Index(['2', '5', '10', '12', '13', '15', '18', '20', '22', '24', '26', '30',
#        '32', '37', '42', '46', '52', '56', '61', '68', '69', '74', '78', '86',
#        '87', '94', '95', '96', '99', '100', '104', '105', '106', '107', '117',
#        '120', '123', '124', '125', '128', '129', '138', '143', '156', '157',
#        '159', '160', '165', '184', '191', '195', '201', '220', '231', '232',
#        '233', '236', '247', '248', '250', '251', '252', '261', '263', '264',
#        '267', '272', '279', '281', '282', '292', '303', '307', '308', '312',
#        '315', '317', '322', '332', '334', '336', '338', '351', '353', '360',
#        '362', '382', '384', '385', '391', '403', '404', '413', '421', '450',
#        '458'],
#       dtype='object', name='Transformer')
# INFO:linopy.model: Solve problem using Glpk solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 15/15 [00:01<00:00,  8.18it/s]
# Writing continuous variables.: 100%|██████████| 6/6 [00:00<00:00, 19.78it/s]
# INFO:linopy.io: Writing time: 2.2s
# INFO:linopy.solvers:GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --lp C:\Users\ALEJAN~1\AppData\Local\Temp\linopy-problem-bx6c3dip.lp --output
#  C:\Users\ALEJAN~1\AppData\Local\Temp\linopy-solve-u6xc2f1e.sol
# Reading problem data from 'C:\Users\ALEJAN~1\AppData\Local\Temp\linopy-problem-bx6c3dip.lp'...
# 142968 rows, 59640 columns, 263626 non-zeros
# 763664 lines were read
# GLPK Simplex Optimizer 5.0
# 142968 rows, 59640 columns, 263626 non-zeros
# Preprocessing...
# 22930 rows, 38242 columns, 122190 non-zeros
# Scaling...
#  A: min|aij| =  1.485e-02  max|aij| =  1.974e+02  ratio =  1.329e+04
# GM: min|aij| =  1.911e-01  max|aij| =  5.233e+00  ratio =  2.738e+01
# EQ: min|aij| =  3.652e-02  max|aij| =  1.000e+00  ratio =  2.738e+01
# Constructing initial basis...
# Size of triangular part is 22381
#       0: obj =   4.717735394e+08 inf =   1.231e+08 (17339)
#    4358: obj =   8.165442610e+07 inf =   5.098e+07 (14464) 30
#    8286: obj =   5.719348932e+07 inf =   3.071e+07 (11986) 30
#   11854: obj =   5.391363402e+07 inf =   2.202e+07 (9953) 27
#   15361: obj =   5.475475754e+07 inf =   1.671e+07 (8209) 26
#   18417: obj =   5.125785252e+07 inf =   1.324e+07 (6936) 21
#   21070: obj =   4.854082566e+07 inf =   1.085e+07 (6016) 19
#   23644: obj =   4.398469875e+07 inf =   8.300e+06 (5064) 18
#   26091: obj =   3.892485579e+07 inf =   6.241e+06 (4254) 17
#   28709: obj =   3.481894379e+07 inf =   4.637e+06 (3523) 16
#   30431: obj =   3.417158737e+07 inf =   3.815e+06 (3043) 12
#   32932: obj =   3.329726025e+07 inf =   2.722e+06 (2420) 14
#   34980: obj =   3.193976254e+07 inf =   1.803e+06 (1771) 11
#   36953: obj =   3.130100638e+07 inf =   1.314e+06 (1389) 12
#   38907: obj =   3.071289585e+07 inf =   7.858e+05 (922) 9
#   40781: obj =   3.016897384e+07 inf =   5.043e+05 (659) 9
#   42046: obj =   2.989322153e+07 inf =   3.636e+05 (520) 8
#   43669: obj =   2.917119866e+07 inf =   1.940e+05 (347) 6
#   45263: obj =   2.978752163e+07 inf =   7.585e+04 (166) 8
#   46767: obj =   2.974101223e+07 inf =   7.509e+03 (41) 8
#   47905: obj =   3.046654464e+07 inf =   2.079e-08 (0) 5
# * 49697: obj =   2.647849028e+07 inf =   1.038e-08 (12848) 9
# * 51436: obj =   2.391912007e+07 inf =   2.076e-08 (13171) 11
# * 52976: obj =   2.179532308e+07 inf =   3.113e-08 (9265) 11
# * 54796: obj =   1.970012156e+07 inf =   2.076e-08 (11345) 10
# * 56370: obj =   1.800080962e+07 inf =   1.038e-08 (10384) 11
# * 58060: obj =   1.621734401e+07 inf =   1.038e-08 (11119) 11
# * 59667: obj =   1.462627725e+07 inf =   2.076e-08 (7349) 12
# * 61355: obj =   1.307171775e+07 inf =   1.038e-08 (11006) 11
# * 62973: obj =   1.155603531e+07 inf =   2.076e-08 (9815) 12
# * 64569: obj =   1.069947827e+07 inf =   3.113e-08 (8158) 12
# * 66381: obj =   9.834110974e+06 inf =   4.151e-08 (5545) 13
# * 68137: obj =   9.388836291e+06 inf =   2.076e-08 (5676) 14
# * 69815: obj =   9.210615296e+06 inf =   3.118e-08 (2048) 12
# * 70672: obj =   9.199288041e+06 inf =   3.113e-08 (0) 7
# OPTIMAL LP SOLUTION FOUND
# Time used:   166.4 secs
# Memory used: 105.1 Mb (110205468 bytes)
# Writing basic solution to 'C:\Users\ALEJAN~1\AppData\Local\Temp\linopy-solve-u6xc2f1e.sol'...
#
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 59640 primals, 142968 duals
# Objective: 9.20e+06
# Solver model: not available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-fix-p-lower, Generator-fix-p-upper, Line-fix-s-lower, Line-fix-s-upper, Transformer-fix-s-lower, Transformer-fix-s-upper, StorageUnit-fix-p_dispatch-lower, StorageUnit-fix-p_dispatch-upper, StorageUnit-fix-p_store-lower, StorageUnit-fix-p_store-upper, StorageUnit-fix-state_of_charge-lower, StorageUnit-fix-state_of_charge-upper, Kirchhoff-Voltage-Law, StorageUnit-energy_balance were not assigned to the network.
# ('ok', 'optimal')

# %% [markdown]
# Now, we can also plot model outputs, like the calculated power flows on the network map.

# %%
line_loading = n.lines_t.p0.iloc[0].abs() / n.lines.s_nom / n.lines.s_max_pu * 100  # %
n
# Out:
# PyPSA Network 'scigrid-de'
# Components:
#  - Bus: 585
#  - Carrier: 15
#  - Generator: 1423
#  - Line: 852
#  - Load: 489
#  - StorageUnit: 38
#  - SubNetwork: 1
#  - Transformer: 96
# Snapshots: 24

# %%
norm = plt.Normalize(vmin=0, vmax=100)

fig = plt.figure(figsize=(7, 7))
ax = plt.axes(projection=ccrs.EqualEarth())

n.plot(
    ax=ax,
    bus_sizes=0,
    line_colors=line_loading,
    line_norm=norm,
    line_cmap="plasma",
    line_widths=n.lines.s_nom / 1000,
)

plt.colorbar(
    plt.cm.ScalarMappable(cmap="plasma", norm=norm),
    ax=ax,
    label="Relative line loading [%]",
    shrink=0.6,
)
# Out:
# c:\Users\Alejandro\miniconda3\envs\pypsa-earth\lib\site-packages\cartopy\mpl\feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '

# %% [markdown]
# Or plot the hourly dispatch grouped by carrier:

# %%
p_by_carrier = n.generators_t.p.T.groupby(n.generators.carrier).sum().T.div(1e3)

# %%
fig, ax = plt.subplots(figsize=(11, 4))

p_by_carrier.plot(
    kind="area",
    ax=ax,
    linewidth=0,
    cmap="tab20b",
)

ax.legend(ncol=5, loc="upper left", frameon=False)

ax.set_ylabel("GW")

ax.set_ylim(0, 80);

# %% [markdown]
# Or plot the aggregate dispatch of the pumped hydro storage units and the state of charge throughout the day:

# %%
fig, ax = plt.subplots()

p_storage = n.storage_units_t.p.sum(axis=1).div(1e3)
state_of_charge = n.storage_units_t.state_of_charge.sum(axis=1).div(1e3)

p_storage.plot(label="Pumped hydro dispatch [GW]", ax=ax)
state_of_charge.plot(label="State of charge [GWh]", ax=ax)

ax.grid()
ax.legend()
ax.set_ylabel("MWh or MW")
# Out:
# Text(0, 0.5, 'MWh or MW')

# %% [markdown]
# Or plot the locational marginal prices (LMPs):

# %%
fig = plt.figure(figsize=(7, 7))
ax = plt.axes(projection=ccrs.EqualEarth())

norm = plt.Normalize(vmin=0, vmax=100)  # €/MWh

n.plot(
    ax=ax,
    bus_colors=n.buses_t.marginal_price.mean(),
    bus_cmap="plasma",
    bus_norm=norm,
    bus_alpha=0.7,
)

plt.colorbar(
    plt.cm.ScalarMappable(cmap="plasma", norm=norm),
    ax=ax,
    label="LMP [€/MWh]",
    shrink=0.6,
)
# Out:
# c:\Users\Alejandro\miniconda3\envs\pypsa-earth\lib\site-packages\cartopy\mpl\feature_artist.py:144: UserWarning: facecolor will have no effect as it has been defined as "never".
#   warnings.warn('facecolor will have no effect as it has been '
